# %%
# Step 4: Evaluation and Comparison Across Models
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ========== Input Model Scores ========== #

# Insight 1: Attrition
insight1 = pd.DataFrame({
    'Model': ['Logistic Regression', 'Random Forest', 'KNN'],
    'Accuracy': [86.65, 86.17, 86.39],
    'Precision': [53.19, 50.00, 52.63],
    'Recall': [40.98, 8.20, 16.39],
    'F1 Score': [46.30, 14.08, 25.00]
})

# Insight 2: Performance Rating (macro-average)
insight2 = pd.DataFrame({
    'Model': ['Logistic Regression', 'Random Forest', 'KNN'],
    'Accuracy': [99.55, 100.00, 87.07],
    'Precision': [99.06, 100.00, 75.65],
    'Recall': [99.06, 100.00, 58.75],
    'F1 Score': [99.06, 100.00, 61.26]
})

# Insight 3: Job Hopper
insight3 = pd.DataFrame({
    'Model': ['Logistic Regression', 'Random Forest', 'KNN'],
    'Accuracy': [99.77, 100.00, 68.93],
    'Precision': [100.00, 100.00, 72.86],
    'Recall': [99.50, 100.00, 50.75],
    'F1 Score': [99.75, 100.00, 59.82]
})

# %%
# ========== Function to Plot Bar Chart ========== #
def plot_comparison_table(df, title):
    print("\n" + title + "\n")
    display(df.round(2))
    
    metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
    df_melted = df.melt(id_vars='Model', value_vars=metrics, var_name='Metric', value_name='Score')
    
    plt.figure(figsize=(10, 6))
    sns.barplot(data=df_melted, x='Metric', y='Score', hue='Model')
    plt.title(title)
    plt.ylabel("Score (%)")
    plt.ylim(0, 110)
    plt.legend(title='Model')
    plt.grid(True, axis='y')
    plt.show()

# %%
# ========== Display Tables and Charts ========== #
plot_comparison_table(insight1, "Insight 1: Predicting Attrition")
plot_comparison_table(insight2, "Insight 2: Predicting Performance Rating")
plot_comparison_table(insight3, "Insight 3: Predicting Job Hopper")
# Out:
# Insight 1: Predicting Attrition
#                  Model  Accuracy  Precision  Recall  F1 Score
# 0  Logistic Regression     86.65      53.19   40.98     46.30
# 1        Random Forest     86.17      50.00    8.20     14.08
# 2                  KNN     86.39      52.63   16.39     25.00
# Insight 2: Predicting Performance Rating
#                  Model  Accuracy  Precision  Recall  F1 Score
# 0  Logistic Regression     99.55      99.06   99.06     99.06
# 1        Random Forest    100.00     100.00  100.00    100.00
# 2                  KNN     87.07      75.65   58.75     61.26
# Insight 3: Predicting Job Hopper
#                  Model  Accuracy  Precision  Recall  F1 Score
# 0  Logistic Regression     99.77     100.00   99.50     99.75
# 1        Random Forest    100.00     100.00  100.00    100.00
# 2                  KNN     68.93      72.86   50.75     59.82

# %%
# ========== Line Chart Across All Models (Per Metric) ========== #
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

for i, (df, title) in enumerate(zip([insight1, insight2, insight3], 
                                    ["Insight 1: Attrition", "Insight 2: Performance Rating", "Insight 3: Job Hopper"])):
    plt.figure(figsize=(10, 6))
    for j in range(len(df)):
        plt.plot(metrics, df.iloc[j, 1:], marker='o', label=df['Model'][j])
    plt.title(f"Metric Trends Across Models - {title}")
    plt.xlabel("Metrics")
    plt.ylabel("Score (%)")
    plt.ylim(0, 110)
    plt.legend()
    plt.grid(True)
    plt.show()
